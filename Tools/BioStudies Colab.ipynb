# %% [markdown]
# Get StarDist

# %%
# !wget -r ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/Stardist_v2 --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# Noise2Void (2D)

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/Noise2Void (2D)/" --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# YoloV2 dataset_v1

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/YoloV2 dataset_v1/" --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# Noise2Void (2D)

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/Noise2Void (2D)/" --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# Label-free prediction (fnet)

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/Label-free prediction (fnet) v2/" --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# DeepSTORM

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/DeepSTORM dataset_v1/" --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# pix2pix

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/pix2pix Actin to Dapi dataset_v1/" --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# Noise2Void

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/Noise2Void (3D)/" --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# CycleGan

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/CycleGAN SDCM to SRRF_v1/" --show-progress -q --cut-dirs=7 -nH -np

# %% [markdown]
# CARE (2D)

# %%
# !wget -r "ftp://ftp.ebi.ac.uk/biostudies/nfs/S-BSST/666/S-BSST666/Files/ZeroCostDl4Mic/CARE (2D)/" --show-progress -q --cut-dirs=7 -nH -np
# Out:
# CARE (2D)/.listing      [ <=>                ]     186  --.-KB/s    in 0.02s
# CARE (2D)/CARE (2D)     [ <=>                ]     445  --.-KB/s    in 0.007s
# CARE (2D)/CARE (2D)     [ <=>                ]     247  --.-KB/s    in 0s
# CARE (2D)/CARE (2D) 100%[===================>]   4.00M  3.83MB/s    in 1.0s
# CARE (2D)/CARE (2D) 100%[===================>]   4.00M  3.68MB/s    in 1.1s
# CARE (2D)/CARE (2D)     [ <=>                ]     247  --.-KB/s    in 0s
# CARE (2D)/CARE (2D) 100%[===================>]   4.00M  3.71MB/s    in 1.1s
# CARE (2D)/CARE (2D) 100%[===================>]   4.00M  3.68MB/s    in 1.1s
# CARE (2D)/CARE (2D)     [ <=>                ]   1.49K  --.-KB/s    in 0.005s
# CARE (2D)/CARE (2D) 100%[===================>]   4.00M  3.82MB/s    in 1.0s
# CARE (2D)/CARE (2D) 100%[===================>]   4.00M  3.64MB/s    in 1.1s
# CARE (2D)/CARE (2D) 100%[===================>]   4.00M  3.67MB/s    in 1.1s
# ...
