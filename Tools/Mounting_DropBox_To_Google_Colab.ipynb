# %% [markdown]
# <p><img alt="Drive logo" height="35px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="3px"></p>
#
# # **Mounting DropBox in Google Colab**

# %% [markdown]
# # **1. Steps to follow on your local computer**

# %% [markdown]
# ##1.1 Visit the [Rclone website](https://rclone.org/downloads/) and download the latest Rclone version compatible with your os.
# ![local-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##1.2 Extract the content of the zip file that you just downloaded
# ![step-0-download-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##1.3 Type "CMD" in the windows search menu, and open Command Prompt.
# ![step-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 1.4 Go inside the main folder that you have extracted/unzipped the file that you just downloaded, and copy the path/address from the top address bar.![step-0-download-4-get path-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 1.5 Go back to the Commmand Prompt, and type cd followd by a space and then paste the path that you just copied and press enter.
# ![step-1-type cd and paste the path you coppied.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 1.6 ⚠️🚨 Make sure you are loged-in into your DropBox account before proceeding to the next step!
# ![login first.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 1.7 In the command prompt type the line below and press enter:
# rclone.exe authorize "dropbox"
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##1.8 After pressing enter in the previous step, a new browser tab will pop-up, that asks you to grant permission to this app to access to your Dropbox profile.
#
# ![rclone access.jpg](data:image/jpeg;base64,...)
#
# 1. 🔍 Diclosure:
#
#     Rclone is an open source, multi threaded, command line computer program to manage or migrate content on cloud and other high latency storage. Its capabilities include sync, transfer, crypt, cache, union, compress and mount. The rclone website lists supported backends including S3, and Google Drive.
#
#     Rclone is under [MIT License🎓](https://en.wikipedia.org/wiki/MIT_License).
#
#     For further info please visit their  [Wikipedia](https://en.wikipedia.org/wiki/Rclone) page.

# %% [markdown]
# ## 1.9 Once you click on "Yes":
# 1. a new tab will open that shows you Success! ✅
# ![success.jpg](data:image/jpeg;base64,...)
# 3. ⚠️ Make sure you do not close the command prompt, further steps requires to copy and paste this access token into a specific field.

# %% [markdown]
# ##1.10 Copy the bracket containing the access token, and paste them in the relevant field once you reached the step 9 in next section.
#
# This is Tom 🤖, remember him!
#
# ![access token.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 2. **Steps to follow in Google colab**

# %% [markdown]
# ## 2.1 install dependencies

# %%
#@markdown ##Press play to install rclone in Google Colab
# !curl  https://rclone.org/install.sh | sudo bash
print('━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━')
print('✔️ Rclone has been successfully')

# %% [markdown]
# ## 2.2 Set your configs ⚙️ manually ⌨️ - Click on the cell below to expand, and then follow the instructions 📖

# %%
#@markdown ##Press play to configure Dropbox.

#@markdown ##**Reply to the following fields in the order listed below:**

#@markdown 1️⃣. Type ' n ' in the 1st empty field and press enter.

#@markdown 2️⃣. Type ' Dropbox ' in the 2nd empty field and press enter (case sensitive, Capslock off).

#@markdown 3️⃣. Type the ' number ' that affiliates with Dropbox in the 3rd empty field and press enter (for example, in rclone v1.56.0 this number is '11').

#@markdown 4️⃣. Do not type anything in the 4th empty field and press enter.

#@markdown 5️⃣. Do not type anything in the 5th empty field and press enter.

#@markdown 6️⃣. In response to the 6th field, " Edit advanced config? ", type 'n' and press enter.

#@markdown 7️⃣. In response to the 7th field, " Use auto config? ", type 'n' and press enter.

#@markdown 8️⃣. In response to the 8th field " config_token> ", copy(ctrl+c) and paste(ctrl+v) the "access_token" that you have given locally on your CMD/Terminal. (Hint: go back to Tom🤖!)

#@markdown 9️⃣. As an example, the access token should have this kind of structure: {"access_token":"token-randomly generated combination of letters, numbers, etc.","expiry":"2021-09-14T20:29:54.1228917+03:00"}

#@markdown 🔟. In response to the 9th field, beginning with "Yes this is OK (default)", type "y", and press enter.

#@markdown 1️⃣1️⃣. In response to the last field, type ' q ' and press enter.

# !rclone config 
print('━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━')
# !sudo mkdir /content/dropbox
# !nohup rclone --vfs-cache-mode writes mount dropbox: /content/dropbox &
print('━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━')
print ('✔️ You have successfully mounted your "Dropbox" to google colab!')
print('━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━')
print ('🎉 Have some cookies 🍪 you deserve it! ')
